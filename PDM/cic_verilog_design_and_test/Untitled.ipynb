# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import os

# %%
data_mt = pd.read_csv("yl1_decV2.csv")

# %%
data_tb = pd.read_csv("output.csv")

# %%
data_tb.columns
# Out:
# Index(['data_in', 'data_out_L1', 'data_out_cic'], dtype='object')

# %%
#tb dec
dec_data = []
count=0
for i in data_tb['data_out_cic']:
    count = count + 1
    if count == 10:
        dec_data.append(i)
        count = 0

# %%
dec_data
# Out:
# [0,
#  8,
#  17,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
#  20,
#  24,
#  21,
#  13,
#  8,
#  12,
# ...

# %%
plt.figure(figsize=(12, 6), dpi=80)
plt.plot(list(data_mt['y_dec_mt'][200:400]), linewidth = 7)
plt.plot(dec_data[200:400])

# %%
plt.figure(figsize=(12, 6), dpi=80)
plt.plot(list(data_mt['y_dec_mt'][400:600]), linewidth = 7)
plt.plot(dec_data[400:600])

# %%
mean_squared_error(data_mt['y_dec_mt'],dec_data)
# Out:
# 0.001

# %%
dec_data[0:5]
# Out:
# [0, 8, 17, 24, 21]

# %%
data_mt['y_dec_mt']
# Out:
# 0       1
# 1       8
# 2      17
# 3      24
# 4      21
#        ..
# 995    17
# 996     7
# 997     5
# 998    15
# 999    25
# Name: y_dec_mt, Length: 1000, dtype: int64

# %%
os.system("iverilog cic.v tb_cic.v")
# Out:
# 0

# %%
os.system("./a.out")
# Out:
# 0

# %%
plt.figure(figsize=(12, 6), dpi=80)
plt.plot(list(data_mt['y_dec_mt'] - dec_data), linewidth = 7)
